# %%
import pandas as pd

# 显式指定使用 fastparquet 引擎
df = pd.read_parquet("tickets_jp.parquet", engine="fastparquet")

print("Parquet 中的所有列名:", df.columns.tolist())

if "利用可能設備" in df.columns:
    print(df["利用可能設備"].dropna().head())
# Out:
# Parquet 中的所有列名: ['チケットID', 'チケット名', '運営会社', '全運営会社', '会社数', '联名フラグ', '地域コード', '地域', '地域(中)', '跨地域', '発売タイプコード', '発売タイプ', '発売タイプ(中)', '媒体', '紙チケット', 'スマホチケット', '発売状況コード', '発売状況図例', '発売開始', '発売終了', '大人料金', '小人料金', '最低料金', '料金', '有効期間', '有効日数', '発売期間', '利用期間', 'フリー区間', '区間地図', '利用可能設備', '制限事項', '制限数', '発売箇所', '問合せ', '備考', '公式URL', '公式リンク', '拡張項目', '詳細URL', '保存ファイル', '表示順', '取得日時', 'タイトル', '発売数量', '申込期間', '申込場所', '元索引']
# 0    新幹線 在来線特急・急行 快速・普通 ＢＲＴ 宮島航路 \n のぞみ／みずほ号 グランクラス...
# 1    新幹線 在来線特急・急行 快速・普通 ＢＲＴ 宮島航路 \n のぞみ／みずほ号 グランクラス...
# 2    東北・上越・北陸新幹線 北海道新幹線 在来線特急・急行 快速・普通 ＢＲＴ \n 寝台車 グ...
# 3    東海道新幹線 北海道･東北･秋田･山形 \n 上越･北陸新幹線 在来線特急/急行 快速・普通...
# 4    東海道新幹線 北海道新幹線 東北･秋田･山形 \n 上越･長野新幹線 在来線特急/急行 快速...
# Name: 利用可能設備, dtype: object
